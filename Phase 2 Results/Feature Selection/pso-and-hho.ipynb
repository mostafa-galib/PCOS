# %% [markdown]
# # Notebook 1 — Metaheuristic Feature Selection (PSO & HHO)
# Searches the clinical features on the **training pool only** (sealed test never opened). Fitness = 5-fold CV MCC of GraphSAGE on the masked features, with a parsimony penalty.

# %%
# Cell 1 
import subprocess, sys
def pip(*args):
    subprocess.run([sys.executable, '-m', 'pip', 'install', *args, '-q'], check=False)

pip('torch_geometric')
pip('imbalanced-learn')
pip('opfunu', '--no-deps')                             
pip('mealpy', '--no-deps')                             
pip('--force-reinstall', '--no-deps', 'numpy>=2,<3')   

print("Done. RESTART THE KERNEL now (Run > Restart & Clear All), then run Cell 2 onward.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 97.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.8/168.8 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.3/423.3 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 87.1 MB/s eta 0:00:00
# Done. RESTART THE KERNEL now (Run > Restart & Clear All), then run Cell 2 onward.

# %%
# Cell 2 — Imports, seed, config.
import os, gc, json, random, warnings
warnings.filterwarnings('ignore')
import numpy as np, pandas as pd
import torch, torch.nn.functional as F
from torch.nn import Linear
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv
from torch_geometric.utils import coalesce
from gensim.models import Word2Vec
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.feature_selection import mutual_info_classif
from imblearn.over_sampling import SMOTE

import mealpy
from mealpy import FloatVar, PSO, HHO
print("mealpy version:", mealpy.__version__)   # <-- record this for the thesis

GLOBAL_SEED = 42
def set_seed(s):
    random.seed(s); np.random.seed(s); torch.manual_seed(s)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(s); torch.cuda.manual_seed_all(s)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(s)
set_seed(GLOBAL_SEED)
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

CONFIG = {
    'DATA_PATH'   : '/kaggle/input/datasets/monamehrun/pcos-cleaned-dataset/pcos_cleaned.csv',
    'TARGET_COL'  : 'PCOS',
    'OUTPUT_DIR'  : '/kaggle/working/',
    'TEST_SIZE'   : 0.20,
    'SEED'        : GLOBAL_SEED,
    'K_NEIGHBOURS': 10,
    'N2V_DIM'     : 64,
    'N2V_WALK_LEN': 20,
    'N2V_CONTEXT' : 10,
    'N2V_WALKS'   : 6,     
    'N2V_EPOCHS'  : 20,     
    'N2V_LR'      : 0.01,
    'HIDDEN_DIM'  : 64,
    'DROPOUT'     : 0.3,
    'LR'          : 0.001,
    'WEIGHT_DECAY': 1e-4,
    'EPOCHS'      : 90,     
    'PATIENCE'    : 20,     
}

# Feature-selection search parameters.
SEARCH = {
    'N_FEATURES'  : None,   # set in Cell 3 after data load
    'N_FOLDS'     : 3,      # 5-fold fitness (search). Final subsets get 10-fold + sealed test later.
    'ALPHA'       : 0.90,   # parsimony: fitness = A*MCC - (1-A)*(n_selected / N_FEATURES)
    'MIN_FEATURES': 3,      # guard: fewer than this -> penalised, no training
    'POP_SIZE'    : 15,     # lower POP_SIZE / EPOCH if a Kaggle session risks timing out
    'EPOCH'       : 20,     # optimizer ITERATIONS (not GNN epochs)
    'MI_K'        : 20,     # mutual-information filter baseline: features kept
}
print("Config loaded. Device:", DEVICE)
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7b872c5a91c0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 1005, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 1187, in _make_controller_from_path
#     lib_controller = controller_class(
#                      ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 114, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/ctypes/__init__.py", line 379, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: /usr/local/lib/python3.12/dist-packages/numpy.libs/libscipy_openblas64_-32a4b2a6.so: cannot open shared object file: No such file or directory
# mealpy version: 3.0.3
# Config loaded. Device: cuda

# %%
# Cell 3 — Load data
df = pd.read_csv(CONFIG['DATA_PATH'])
y = df[CONFIG['TARGET_COL']].values.astype(np.int64)
X = df.drop(columns=[CONFIG['TARGET_COL']]).values.astype(np.float32)
feature_names = df.drop(columns=[CONFIG['TARGET_COL']]).columns.tolist()

X_train, _Xte, y_train, _yte = train_test_split(
    X, y, test_size=CONFIG['TEST_SIZE'], stratify=y, random_state=CONFIG['SEED'])
del _Xte, _yte  

SEARCH['N_FEATURES'] = X_train.shape[1]
print(f"Training pool: {X_train.shape[0]} patients x {X_train.shape[1]} features "
      f"(PCOS+={int(y_train.sum())})")
# Out:
# Training pool: 432 patients x 48 features (PCOS+=141)

# %%
# Cell 4 — Pipeline utilities
def build_knn_graph(features_scaled, k=10):
    n = len(features_scaled)
    sim = cosine_similarity(features_scaled); np.fill_diagonal(sim, -2.0)
    src, dst, wts = [], [], []
    for i in range(n):
        for j in np.argpartition(sim[i], -k)[-k:]:
            w = float(max(0.0, sim[i][j])); src += [i, j]; dst += [j, i]; wts += [w, w]
    ei = torch.tensor([src, dst], dtype=torch.long); ew = torch.tensor(wts, dtype=torch.float)
    return coalesce(ei, ew, num_nodes=n, reduce='max')

def add_synthetic_nodes(ei, ew, X_real_sc, X_syn_sc, k=10):
    n_real, n_syn = len(X_real_sc), len(X_syn_sc)
    if n_syn == 0: return ei, ew
    sim = cosine_similarity(X_syn_sc, X_real_sc)
    src, dst, wts = [], [], []
    for i in range(n_syn):
        s = n_real + i
        for j in np.argpartition(sim[i], -k)[-k:]:
            w = float(max(0.0, sim[i][j])); src += [s, j]; dst += [j, s]; wts += [w, w]
    aug_ei = torch.cat([ei, torch.tensor([src, dst], dtype=torch.long)], dim=1)
    aug_ew = torch.cat([ew, torch.tensor(wts, dtype=torch.float)])
    return coalesce(aug_ei, aug_ew, num_nodes=n_real + n_syn, reduce='max')

def add_val_nodes(ei_aug, ew_aug, X_real_sc, X_val_sc, k=10, n_train_aug=None):
    n_real, n_val = len(X_real_sc), len(X_val_sc)
    if n_train_aug is None: n_train_aug = n_real
    sim = cosine_similarity(X_val_sc, X_real_sc)
    src, dst, wts = [], [], []
    for i in range(n_val):
        v = n_train_aug + i
        for j in np.argpartition(sim[i], -k)[-k:]:
            w = float(max(0.0, sim[i][j])); src += [v, j]; dst += [j, v]; wts += [w, w]
    comb_ei = torch.cat([ei_aug, torch.tensor([src, dst], dtype=torch.long)], dim=1)
    comb_ew = torch.cat([ew_aug, torch.tensor(wts, dtype=torch.float)])
    return comb_ei, comb_ew

def _random_walks(edge_index, num_nodes, walk_length, walks_per_node, seed=42):
    import random as _r; _r.seed(seed)
    adj = [[] for _ in range(num_nodes)]
    ei = edge_index.cpu().numpy()
    for s, d in zip(ei[0], ei[1]): adj[int(s)].append(int(d))
    walks, nodes = [], list(range(num_nodes))
    for _ in range(walks_per_node):
        _r.shuffle(nodes)
        for start in nodes:
            walk = [start]
            for _ in range(walk_length - 1):
                nbrs = adj[walk[-1]]
                if nbrs: walk.append(_r.choice(nbrs))
                else: break
            walks.append([str(n) for n in walk])
    return walks

def train_node2vec(edge_index, num_nodes, cfg):
    walks = _random_walks(edge_index, num_nodes, cfg['N2V_WALK_LEN'], cfg['N2V_WALKS'], cfg['SEED'])
    w2v = Word2Vec(sentences=walks, vector_size=cfg['N2V_DIM'], window=cfg['N2V_CONTEXT'],
                   min_count=0, sg=1, workers=1, seed=cfg['SEED'], epochs=cfg['N2V_EPOCHS'])
    emb = np.zeros((num_nodes, cfg['N2V_DIM']), dtype=np.float32)
    for idx in range(num_nodes):
        if str(idx) in w2v.wv: emb[idx] = w2v.wv[str(idx)]
    return emb

def inductive_n2v(X_new_sc, X_train_sc, n2v_train, k=10):
    sim = cosine_similarity(X_new_sc, X_train_sc)
    out = np.zeros((len(X_new_sc), n2v_train.shape[1]), dtype=np.float32)
    for i in range(len(X_new_sc)):
        tk = np.argpartition(sim[i], -k)[-k:]
        w = np.maximum(sim[i][tk], 0.0); ws = w.sum()
        w = w / ws if ws > 1e-9 else np.ones(k) / k
        out[i] = (n2v_train[tk] * w[:, None]).sum(axis=0)
    return out

class GraphSAGE(torch.nn.Module):
    def __init__(self, in_ch, hidden_ch, out_ch, dropout=0.3):
        super().__init__()
        self.c1 = SAGEConv(in_ch, hidden_ch); self.c2 = SAGEConv(hidden_ch, hidden_ch)
        self.lin = Linear(hidden_ch, out_ch); self.drop = dropout
    def forward(self, x, edge_index, edge_weight=None):
        x = F.relu(self.c1(x, edge_index)); x = F.dropout(x, self.drop, self.training)
        x = F.relu(self.c2(x, edge_index)); x = F.dropout(x, self.drop, self.training)
        return self.lin(x)

print("Pipeline utilities loaded.")
# Out:
# Pipeline utilities loaded.

# %%
# Cell 5 — Fitness. 5-fold CV MCC of GraphSAGE on the masked features (graph + Node2Vec
# rebuilt inside every fold => no leakage), combined with a parsimony penalty. 
def evaluate_subset(mask, X_pool, y_pool, cfg, n_folds):
    # returns (mean 5-fold val MCC, n_selected) using only the masked clinical columns
    cols = np.where(np.asarray(mask) == 1)[0]
    Xp = X_pool[:, cols]; n_clin = Xp.shape[1]; in_ch = n_clin + cfg['N2V_DIM']
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=cfg['SEED'])
    mccs = []
    for fold_idx, (tr, va) in enumerate(skf.split(Xp, y_pool)):
        try:
            X_tr, y_tr = Xp[tr], y_pool[tr]; X_va, y_va = Xp[va], y_pool[va]
            sc = StandardScaler(); X_tr_sc = sc.fit_transform(X_tr); X_va_sc = sc.transform(X_va)
            ei, ew = build_knn_graph(X_tr_sc, k=cfg['K_NEIGHBOURS']); n_real = len(X_tr_sc)
            n2v_tr = train_node2vec(ei, n_real, cfg)
            X_tr_full = np.concatenate([X_tr_sc, n2v_tr], axis=1)
            X_tr_sm, y_tr_sm = SMOTE(random_state=cfg['SEED'], k_neighbors=5).fit_resample(X_tr_full, y_tr)
            n_train_aug = len(X_tr_sm)
            if n_train_aug > n_real:
                ei, ew = add_synthetic_nodes(ei, ew, X_tr_sc, X_tr_sm[n_real:, :n_clin], k=cfg['K_NEIGHBOURS'])
            n2v_va = inductive_n2v(X_va_sc, X_tr_sc, n2v_tr, k=cfg['K_NEIGHBOURS'])
            X_va_full = np.concatenate([X_va_sc, n2v_va], axis=1)
            ei, ew = add_val_nodes(ei, ew, X_tr_sc, X_va_sc, k=cfg['K_NEIGHBOURS'], n_train_aug=n_train_aug)
            X_all = np.concatenate([X_tr_sm, X_va_full], axis=0); y_all = np.concatenate([y_tr_sm, y_va])
            tm = torch.zeros(len(X_all), dtype=torch.bool); tm[:n_train_aug] = True
            vm = torch.zeros(len(X_all), dtype=torch.bool); vm[n_train_aug:] = True
            data = Data(x=torch.tensor(X_all, dtype=torch.float), edge_index=ei, edge_weight=ew,
                        y=torch.tensor(y_all, dtype=torch.long), train_mask=tm, val_mask=vm).to(DEVICE)
            n_neg, n_pos = float((y_tr_sm == 0).sum()), float((y_tr_sm == 1).sum())
            crit = torch.nn.CrossEntropyLoss(
                weight=torch.tensor([1.0, n_neg / n_pos], dtype=torch.float).to(DEVICE))
            set_seed(cfg['SEED'] + fold_idx)
            model = GraphSAGE(in_ch, cfg['HIDDEN_DIM'], 2, cfg['DROPOUT']).to(DEVICE)
            opt = torch.optim.Adam(model.parameters(), lr=cfg['LR'], weight_decay=cfg['WEIGHT_DECAY'])
            sch = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, mode='max', factor=0.5, patience=15, min_lr=1e-6)
            best_auroc, wait, best_w = 0.0, 0, None
            for _ in range(cfg['EPOCHS']):
                model.train(); opt.zero_grad()
                out = model(data.x, data.edge_index, data.edge_weight)
                loss = crit(out[data.train_mask], data.y[data.train_mask])
                if torch.isnan(loss): break
                loss.backward(); opt.step()
                model.eval()
                with torch.no_grad():
                    pv = torch.softmax(model(data.x, data.edge_index, data.edge_weight)[data.val_mask],
                                       dim=1)[:, 1].cpu().numpy()
                try: a = roc_auc_score(y_va, pv)
                except: a = 0.0
                sch.step(a)
                if a > best_auroc + 1e-4:
                    best_auroc, wait = a, 0
                    best_w = {k: v.clone() for k, v in model.state_dict().items()}
                else:
                    wait += 1
                    if wait >= cfg['PATIENCE']: break
            if best_w is not None: model.load_state_dict(best_w)
            model.eval()
            with torch.no_grad():
                pr = model(data.x, data.edge_index, data.edge_weight)[data.val_mask].argmax(dim=1).cpu().numpy()
            mccs.append(matthews_corrcoef(y_va, pr))
            del model, data, opt, sch, crit; gc.collect()
            if torch.cuda.is_available(): torch.cuda.empty_cache()
        except Exception:
            mccs.append(-1.0)   # failed fold -> worst, never NaN
    return float(np.mean(mccs)), len(cols)

def make_fitness(X_pool, y_pool, cfg, search):
    cache = {}                                             # exact memoization: same mask -> same fitness
    def fitness(solution):
        mask = (np.asarray(solution) >= 0.5).astype(int)   # threshold continuous -> binary
        key = tuple(mask.tolist())
        if key in cache:                                   # skip re-evaluating a mask already seen
            return cache[key]
        n_sel = int(mask.sum())
        if n_sel < search['MIN_FEATURES']:
            cache[key] = -2.0; return -2.0                 
        mcc, n = evaluate_subset(mask, X_pool, y_pool, cfg, search['N_FOLDS'])
        val = search['ALPHA'] * mcc - (1 - search['ALPHA']) * (n_sel / search['N_FEATURES'])
        cache[key] = val
        return val
    return fitness

print("Fitness ready.")
# Out:
# Fitness ready.

# %%
# Cell 6 — PSO feature selection (mealpy)
fitness_fn = make_fitness(X_train, y_train, CONFIG, SEARCH)
problem = {
    "obj_func": fitness_fn,
    "bounds": FloatVar(lb=[0.0] * SEARCH['N_FEATURES'], ub=[1.0] * SEARCH['N_FEATURES']),
    "minmax": "max",
    "log_to": "console",
}
set_seed(GLOBAL_SEED)
pso = PSO.OriginalPSO(epoch=SEARCH['EPOCH'], pop_size=SEARCH['POP_SIZE'])
pso_best = pso.solve(problem, seed=GLOBAL_SEED)

pso_mask  = (np.asarray(pso_best.solution) >= 0.5).astype(int)
pso_feats = [feature_names[i] for i in np.where(pso_mask == 1)[0]]
pso_mcc, pso_n = evaluate_subset(pso_mask, X_train, y_train, CONFIG, SEARCH['N_FOLDS'])
print(f"\nPSO -> {pso_n} features | 5-fold MCC {pso_mcc:.4f} | fitness {pso_best.target.fitness:.4f}")

# crash-safety: save PSO immediately so a later timeout cannot lose it
with open(os.path.join(CONFIG['OUTPUT_DIR'], 'fs_pso.json'), 'w') as f:
    json.dump({"features": pso_feats, "n": int(pso_n), "cv_mcc_5fold": float(pso_mcc)}, f, indent=2)
print("saved -> fs_pso.json")
# Out:
# INFO:mealpy.swarm_based.PSO.OriginalPSO:OriginalPSO(epoch=20, pop_size=15, c1=2.05, c2=2.05, w=0.4)
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 1, Current best: 0.5739135959205243, Global best: 0.5739135959205243, Runtime: 195.66908 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 2, Current best: 0.5739135959205243, Global best: 0.5739135959205243, Runtime: 196.59297 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 3, Current best: 0.6012835403241371, Global best: 0.6012835403241371, Runtime: 196.69856 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 4, Current best: 0.6090557143749153, Global best: 0.6090557143749153, Runtime: 199.79947 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 5, Current best: 0.6090557143749153, Global best: 0.6090557143749153, Runtime: 199.81077 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 6, Current best: 0.6095433856695965, Global best: 0.6095433856695965, Runtime: 196.68215 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 7, Current best: 0.6095433856695965, Global best: 0.6095433856695965, Runtime: 194.23308 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 8, Current best: 0.6095433856695965, Global best: 0.6095433856695965, Runtime: 193.29376 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 9, Current best: 0.6215806429407599, Global best: 0.6215806429407599, Runtime: 192.94766 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 10, Current best: 0.6335880014342739, Global best: 0.6335880014342739, Runtime: 195.63145 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 11, Current best: 0.6403863973962128, Global best: 0.6403863973962128, Runtime: 197.47661 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 12, Current best: 0.6403863973962128, Global best: 0.6403863973962128, Runtime: 200.08072 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 13, Current best: 0.6503568344551929, Global best: 0.6503568344551929, Runtime: 200.83544 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 14, Current best: 0.6503568344551929, Global best: 0.6503568344551929, Runtime: 200.09258 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 15, Current best: 0.6503568344551929, Global best: 0.6503568344551929, Runtime: 201.74361 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 16, Current best: 0.6503568344551929, Global best: 0.6503568344551929, Runtime: 198.00587 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 17, Current best: 0.6503568344551929, Global best: 0.6503568344551929, Runtime: 184.36763 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 18, Current best: 0.6503568344551929, Global best: 0.6503568344551929, Runtime: 186.67388 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 19, Current best: 0.6631554561504339, Global best: 0.6631554561504339, Runtime: 185.18881 seconds
# INFO:mealpy.swarm_based.PSO.OriginalPSO:>>>Problem: P, Epoch: 20, Current best: 0.6631554561504339, Global best: 0.6631554561504339, Runtime: 201.42642 seconds
# PSO -> 22 features | 5-fold MCC 0.7878 | fitness 0.6632
# saved -> fs_pso.json

# %%
# Cell 7 — HHO feature selection (mealpy)
set_seed(GLOBAL_SEED)
hho = HHO.OriginalHHO(epoch=SEARCH['EPOCH'], pop_size=SEARCH['POP_SIZE'])
hho_best = hho.solve(problem, seed=GLOBAL_SEED)

hho_mask  = (np.asarray(hho_best.solution) >= 0.5).astype(int)
hho_feats = [feature_names[i] for i in np.where(hho_mask == 1)[0]]
hho_mcc, hho_n = evaluate_subset(hho_mask, X_train, y_train, CONFIG, SEARCH['N_FOLDS'])
print(f"\nHHO -> {hho_n} features | 5-fold MCC {hho_mcc:.4f} | fitness {hho_best.target.fitness:.4f}")

# crash-safety: save HHO immediately
with open(os.path.join(CONFIG['OUTPUT_DIR'], 'fs_hho.json'), 'w') as f:
    json.dump({"features": hho_feats, "n": int(hho_n), "cv_mcc_5fold": float(hho_mcc)}, f, indent=2)
print("saved -> fs_hho.json")
# Out:
# INFO:mealpy.swarm_based.HHO.OriginalHHO:OriginalHHO(epoch=20, pop_size=15)
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 1, Current best: 0.5416895476115453, Global best: 0.5416895476115453, Runtime: 135.45661 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 2, Current best: 0.5722498629205834, Global best: 0.5722498629205834, Runtime: 80.44912 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 3, Current best: 0.5722498629205834, Global best: 0.5722498629205834, Runtime: 93.99475 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 4, Current best: 0.5722498629205834, Global best: 0.5722498629205834, Runtime: 79.18699 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 5, Current best: 0.6018289107309539, Global best: 0.6018289107309539, Runtime: 69.03245 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 6, Current best: 0.6094758352768165, Global best: 0.6094758352768165, Runtime: 82.36805 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 7, Current best: 0.6224240995912583, Global best: 0.6224240995912583, Runtime: 93.83652 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 8, Current best: 0.6224240995912583, Global best: 0.6224240995912583, Runtime: 77.74830 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 9, Current best: 0.6224240995912583, Global best: 0.6224240995912583, Runtime: 67.05601 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 10, Current best: 0.6224240995912583, Global best: 0.6224240995912583, Runtime: 12.93896 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 11, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 80.68475 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 12, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 40.79133 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 13, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 67.32620 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 14, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 39.96301 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 15, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 0.00218 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 16, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 0.00425 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 17, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 0.00202 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 18, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 0.00301 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 19, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 0.00220 seconds
# INFO:mealpy.swarm_based.HHO.OriginalHHO:>>>Problem: P, Epoch: 20, Current best: 0.6451813075097124, Global best: 0.6451813075097124, Runtime: 0.00178 seconds
# HHO -> 17 features | 5-fold MCC 0.7562 | fitness 0.6452
# saved -> fs_hho.json

# %%
# Cell 8 — Baselines under the SAME 5-fold fitness: all-features and mutual-information top-K.
all_mask = np.ones(SEARCH['N_FEATURES'], dtype=int)
all_mcc, all_n = evaluate_subset(all_mask, X_train, y_train, CONFIG, SEARCH['N_FOLDS'])
print(f"ALL -> {all_n} features | 5-fold MCC {all_mcc:.4f}")

mi = mutual_info_classif(X_train, y_train, random_state=GLOBAL_SEED)
mi_idx  = np.argsort(mi)[::-1][:SEARCH['MI_K']]
mi_mask = np.zeros(SEARCH['N_FEATURES'], dtype=int); mi_mask[mi_idx] = 1
mi_feats = [feature_names[i] for i in np.where(mi_mask == 1)[0]]
mi_mcc, mi_n = evaluate_subset(mi_mask, X_train, y_train, CONFIG, SEARCH['N_FOLDS'])
print(f"MI  -> {mi_n} features | 5-fold MCC {mi_mcc:.4f}")
# Out:
# ALL -> 48 features | 5-fold MCC 0.6613
# MI  -> 20 features | 5-fold MCC 0.7251

# %%
# Cell 9 — Comparison table
results = {
    "PSO": {"features": pso_feats, "n": int(pso_n), "cv_mcc_5fold": float(pso_mcc)},
    "HHO": {"features": hho_feats, "n": int(hho_n), "cv_mcc_5fold": float(hho_mcc)},
    "ALL": {"features": feature_names, "n": int(all_n), "cv_mcc_5fold": float(all_mcc)},
    "MI":  {"features": mi_feats, "n": int(mi_n), "cv_mcc_5fold": float(mi_mcc)},
    "_meta": {"alpha": SEARCH['ALPHA'], "search_folds": SEARCH['N_FOLDS'],
              "pop_size": SEARCH['POP_SIZE'], "iterations": SEARCH['EPOCH'],
              "seed": GLOBAL_SEED, "mealpy_version": mealpy.__version__},
}
print(f"\n{'Method':<6}{'#Feat':>7}{'5-fold MCC':>13}")
for k in ["PSO", "HHO", "MI", "ALL"]:
    print(f"{k:<6}{results[k]['n']:>7}{results[k]['cv_mcc_5fold']:>13.4f}")

out = os.path.join(CONFIG['OUTPUT_DIR'], 'selected_features.json')
with open(out, 'w') as f: json.dump(results, f, indent=2)
print(f"\nSaved -> {out}   (both PSO and HHO subsets carried forward)")
